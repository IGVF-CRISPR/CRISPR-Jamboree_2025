# %% [markdown]
# ### Running tasks

# %%
# %%writefile nextflow_run.sh
# #!/bin/bash
# MPLBACKEND="notebook"
# conda init
# source ~/.bashrc
# conda activate /opt/micromamba/
#
# # The default nextflow will run the H9 dataset. To run the WTC11 dataset just uncomment the line.
#
# cd ~/jamboree_task/inference; chmod +x bin/*
# cd ~/jamboree_task/inference; nextflow run main.nf -c input_h9.config
# # cd ~/jamboree_task/inference; nextflow run main.nf -c input_wtc11.config
# Out:
# Overwriting nextflow_run.sh

# %%
###
# !bash nextflow_run.sh
# Out:
# no change     /opt/conda/condabin/conda
# no change     /opt/conda/bin/conda
# no change     /opt/conda/bin/conda-env
# no change     /opt/conda/bin/activate
# no change     /opt/conda/bin/deactivate
# no change     /opt/conda/etc/profile.d/conda.sh
# no change     /opt/conda/etc/fish/conf.d/conda.fish
# no change     /opt/conda/shell/condabin/Conda.psm1
# no change     /opt/conda/shell/condabin/conda-hook.ps1
# no change     /opt/conda/lib/python3.12/site-packages/xontrib/conda.xsh
# no change     /opt/conda/etc/profile.d/conda.csh
# no change     /home/jovyan/.bashrc
# No action taken.
#
#  N E X T F L O W   ~  version 24.10.4
#
# Launching `main.nf` [trusting_wing] DSL2 - revision: 0e9db78e1b
#
# [-        ] prepare_user_guide_inference -
#
# [-        ] prepare_user_guide_inference | 0 of 1
# [-        ] inference_sceptre            -
# [-        ] inference_perturbo           -
# [-        ] mergedResults                -
#
# executor >  local (1)
# ...

# %% [markdown]
# ### Calculating the AUROC and AUPRC for sceptre and Perturbo
#
# Pairs_to_test List:
#
# WTC-11: https://docs.google.com/spreadsheets/d/1bTVu80bh0u2Ofs3xVT5gyF0lZpqHpJrAO8_G8meNoD8/edit?gid=0#gid=0
#
# H9: https://docs.google.com/spreadsheets/d/1gCec96Nq-Cp0IfDpaZ_rGoOirYAJfrLp1BIz6NvEYB8/edit?gid=0#gid=0

# %%
# %%bash
# conda init
# source ~/.bashrc
# conda activate /opt/micromamba/
#
# cd jamboree_task/inference; python evaluation_curve.py -i pipeline_outputs/inference_mudata.h5mu
# Out:
# no change     /opt/conda/condabin/conda
# no change     /opt/conda/bin/conda
# bin/conda-env /opt/conda/
# no change     /opt/conda/bin/activate
# no change     /opt/conda/bin/deactivate
# e     /opt/conda/etc/profile.d/conda.sh
# no change     /opt/conda/etc/fish/conf.d/conda.fish
# e     /opt/conda/shell/condabin/Conda.psm1
# no change     /opt/conda/shell/condabin/conda-hook.ps1
#  change     /opt/conda/lib/python3.12/site-packages/xontrib/conda.xsh
# rofile.d/conda.csh/conda/etc/p
# no change     /home/jovyan/.bashrc
# No action taken.
# Reading data from pipeline_outputs/inference_mudata.h5mu
# Processing data...
# Assigning true labels...
# Performing binary evaluation...
#
# Results for sceptre_p_value:
# .991 under Precision-Recall Curve : 0
# Area under Receiver-Operating Curve: 0.917
#
# Results for perturbo_p_value:
# Recall Curve : 0.972-
# Area under Receiver-Operating Curve: 0.807
# Figure(1300x1040)

# %%
from IPython.display import Image, display

display(Image(filename='/home/jovyan/jamboree_task/inference/evaluation_curves.png'))
